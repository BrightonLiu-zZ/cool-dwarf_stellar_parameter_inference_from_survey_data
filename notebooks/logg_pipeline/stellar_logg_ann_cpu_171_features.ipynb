# %% [markdown]
# # Stellar Surface Gravity (logg) Prediction with PyTorch ANN
#
# **Goal**: Train a feedforward neural network to predict stellar surface gravity (logg) from 171 photometric features (color indices) for F, G, K, and M dwarf stars.
#
# **Approach** (based on Gemini recommendations):
# - **Target**: logg (raw values — already in log scale, no additional transform needed)
# - **Loss**: MSE on logg
# - **Architecture**: 4-layer feedforward network with BatchNorm + Dropout
# - **Split**: 70/15/15 train/val/test, stratified by spectral type
# - **Evaluation**: RMSE (dex), MAE, R² (target >0.90), plus diagnostic plots

# %% [markdown]
# ## 1. Imports & Configuration

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import joblib
import warnings
from pathlib import Path

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

warnings.filterwarnings("ignore")
sns.set_context("talk")

DEVICE = torch.device("cpu")  # <--- Modified: Force CPU usage
print(f"Using device: {DEVICE}")

# if DEVICE.type == "cuda":
#     print(f"  GPU: {torch.cuda.get_device_name(0)}")
#     print(f"  VRAM: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")
# --- Reproducibility ---
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
# Out:
# Using device: cpu

# %% [markdown]
# ## 2. Data Loading & Inspection

# %%
# --- Paths ---
PROJECT_ROOT = Path("C:/git_repo/cool-dwarf_stellar_parameter_inference_from_survey_data")
DATA_PATH = PROJECT_ROOT / "data" / "logg_final_df" / "cool_dwarf_catalog_FGKM_consolidated.csv"
RESULTS_DIR = PROJECT_ROOT / "results"
MODELS_DIR = PROJECT_ROOT / "models"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
(RESULTS_DIR / "logg").mkdir(parents=True, exist_ok=True)
(MODELS_DIR / "logg").mkdir(parents=True, exist_ok=True)

# --- Load ---
df = pd.read_csv(DATA_PATH)
print(f"Dataset shape: {df.shape}")
print(f"\nSpectral type distribution:")
print(df["spectral_type_group"].value_counts().sort_index())
print(f"\nlogg range: {df['logg'].min():.2f} — {df['logg'].max():.2f}")
print(f"\nFirst 5 rows:")
df.head()
# Out:
# Dataset shape: (904427, 197)
#
# Spectral type distribution:
# spectral_type_group
# F    274831
# G    578786
# K     18889
# M     31921
# Name: count, dtype: int64
#
# logg range: 3.50 — 5.02
#
# First 5 rows:
#        obsid subclass   gaia_source_id  distance_gaia_pc     teff   logg  \
# 0  300003054       F0  279692565863680       1197.577725  6512.09  4.105
# 1  483006140       F0  279692565863680       1197.577725  6549.88  4.120
# 2  300014173       F6  492516785395968        592.602005  6131.14  4.276
# 3  483006043       F7  492516785395968        592.602005  6123.43  4.270
# 4  757516200       F6  617139556505856       1350.264165  6129.88  4.306
#
#        A_GG      A_BP      A_RP       A_J  ...  COLOR_A_J_A_KS  \
# 0  2.743019  2.867387  2.300888  1.901812  ...        0.222598
# 1  2.760979  2.956954  2.396033  2.025593  ...        0.306546
# 2  3.921653  4.337359  3.612836  3.213820  ...        0.498134
# 3  4.277970  4.636078  3.953510  3.403232  ...        0.350874
# 4  3.702365  4.764616  3.579519  3.170527  ...        0.012281
#
#    COLOR_A_J_A_W1  COLOR_A_J_A_W2  COLOR_A_H_A_KS  COLOR_A_H_A_W1  \
# 0        0.332229        0.241461       -0.019114        0.090517
# 1        0.421578        0.381074        0.029463        0.144495
# 2        0.472155        0.377120        0.083556        0.057577
# 3        0.253590        0.357602        0.138743        0.041460
# 4        0.255204        0.850975       -0.714439       -0.471516
#
#    COLOR_A_H_A_W2  COLOR_A_KS_A_W1  COLOR_A_KS_A_W2  COLOR_A_W1_A_W2  \
# 0       -0.000251         0.109631         0.018863        -0.090768
# 1        0.103991         0.115032         0.074528        -0.040504
# 2       -0.037458        -0.025979        -0.121015        -0.095035
# 3        0.145472        -0.097284         0.006728         0.104012
# 4        0.124255         0.242923         0.838694         0.595771
#
#    spectral_type_group
# 0                    F
# 1                    F
# 2                    F
# 3                    F
# 4                    F
#
# [5 rows x 197 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

# logg histogram by spectral type
for stype in ["F", "G", "K", "M"]:
    subset = df[df["spectral_type_group"] == stype]
    ax.hist(subset["logg"], bins=100, alpha=0.6, label=f"{stype} (n={len(subset):,})")
ax.set_xlabel("logg")
ax.set_ylabel("Count")
ax.set_title("logg Distribution by Spectral Type")
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Feature & Target Definition

# %%
# --- 171 photometric features (color indices) ---
sorted_mags = [
    'A_BAP', 'A_GSD', 'A_ps_g', 'A_BP', 'A_VAP', 'A_ps_r', 'A_RSD', 'A_RAP', 
    'A_GG', 'A_ps_i', 'A_ISD', 'A_RP', 'A_ps_z', 'A_ps_y', 'A_J', 'A_H', 
    'A_KS', 'A_W1', 'A_W2'
]

FEATURE_COLS = []
for i in range(len(sorted_mags)):
    for j in range(i + 1, len(sorted_mags)):
        mag1 = sorted_mags[i]
        mag2 = sorted_mags[j]
        FEATURE_COLS.append(f'COLOR_{mag1}_{mag2}')

TARGET_COL = "logg"

print(f"Number of features: {len(FEATURE_COLS)}")
print(f"Target column: {TARGET_COL}")

# --- Extract arrays ---
X = df[FEATURE_COLS].values.astype(np.float32)
y = df[TARGET_COL].values.astype(np.float32)  # raw logg values (no transform needed)
spectral_types = df["spectral_type_group"].values # for stratified split

# --- Sanity checks ---
assert not np.any(np.isnan(X)), "NaN found in features!"
assert not np.any(np.isinf(X)), "Inf found in features!"
assert not np.any(np.isnan(y)), "NaN found in target!"
print(f"\nNo NaN or Inf in features or target")
print(f"  X shape: {X.shape}")
print(f"  y shape: {y.shape}")
print(f"  logg range: [{y.min():.4f}, {y.max():.4f}]")
# Out:
# Number of features: 171
# Target column: logg
#
# No NaN or Inf in features or target
#   X shape: (904427, 171)
#   y shape: (904427,)
#   logg range: [3.5000, 5.0210]

# %% [markdown]
# ## 4. Train / Validation / Test Split (70 / 15 / 15)
#
# Stratified by spectral type to ensure M dwarfs (~2.4% of data) are adequately represented in all splits.

# %%
# --- Step 1: Split off 70% train, 30% temp ---
X_train, X_temp, y_train, y_temp, st_train, st_temp = train_test_split(
    X, y, spectral_types,
    test_size=0.30,
    random_state=SEED,
    stratify=spectral_types,
)

# --- Step 2: Split temp into 50/50 -> 15% val, 15% test ---
X_val, X_test, y_val, y_test, st_val, st_test = train_test_split(
    X_temp, y_temp, st_temp,
    test_size=0.50,
    random_state=SEED,
    stratify=st_temp,
)

print(f"{'Split':<12} {'Samples':>10}  {'% of total':>10}")
print("-" * 36)
total = len(y)
for name, arr in [("Train", y_train), ("Validation", y_val), ("Test", y_test)]:
    print(f"{name:<12} {len(arr):>10,}  {100*len(arr)/total:>9.1f}%")
print(f"{'Total':<12} {total:>10,}  {100.0:>9.1f}%")

# Verify spectral type proportions are preserved
print(f"\nSpectral type proportions (%):")
print(f"{'Type':<6} {'Full':>8} {'Train':>8} {'Val':>8} {'Test':>8}")
print("-" * 40)
for stype in ["F", "G", "K", "M"]:
    full_pct = 100 * np.sum(spectral_types == stype) / len(spectral_types)
    train_pct = 100 * np.sum(st_train == stype) / len(st_train)
    val_pct = 100 * np.sum(st_val == stype) / len(st_val)
    test_pct = 100 * np.sum(st_test == stype) / len(st_test)
    print(f"{stype:<6} {full_pct:>7.1f}% {train_pct:>7.1f}% {val_pct:>7.1f}% {test_pct:>7.1f}%")
# Out:
# Split           Samples  % of total
# ------------------------------------
# Train           633,098       70.0%
# Validation      135,664       15.0%
# Test            135,665       15.0%
# Total           904,427      100.0%
#
# Spectral type proportions (%):
# Type       Full    Train      Val     Test
# ----------------------------------------
# F         30.4%    30.4%    30.4%    30.4%
# G         64.0%    64.0%    64.0%    64.0%
# K          2.1%     2.1%     2.1%     2.1%
# M          3.5%     3.5%     3.5%     3.5%

# %% [markdown]
# ## 4b. logg-Bin-Balanced Data Augmentation (Training Set Only)
#
# **Error-aware oversampling** — addresses professor feedback to "pull from the empirical distribution, including the errors."
#
# 1. Bin training `logg` into **0.1 dex bins**.
# 2. **Drop edge bins** with fewer than 100 samples (sparse, uninformative).
# 3. For each remaining bin, compute the **empirical per-feature σ** (std within the bin) and **empirical logg σ**.
# 4. Oversample under-represented bins to match the largest bin: each synthetic row = source row + `N(0, σ_feature)` noise per feature + `N(0, σ_logg)` noise on logg.
# 5. `StandardScaler` is fit on the **original (trimmed, un-augmented)** training data.

# %%
# ── Error-aware logg-bin-balanced oversampling (training set only) ───────────

BIN_WIDTH = 0.1          # dex — matches outlier-filtering pipeline
MIN_BIN_SAMPLES = 100    # drop edge bins sparser than this

# logg values are directly in y_train (no inverse transform needed)
logg_train = y_train

# ── 1. Create 0.1 dex bin edges covering the full logg range ─────────────────
bin_lo = np.floor(logg_train.min() / BIN_WIDTH) * BIN_WIDTH
bin_hi = np.ceil(logg_train.max() / BIN_WIDTH) * BIN_WIDTH + BIN_WIDTH
bin_edges = np.arange(bin_lo, bin_hi, BIN_WIDTH)

bin_ids = np.digitize(logg_train, bin_edges)
unique_bins, bin_counts = np.unique(bin_ids, return_counts=True)

print(f"Bin width: {BIN_WIDTH} dex")
print(f"Bin edges: {bin_edges[0]:.2f} – {bin_edges[-1]:.2f}  ({len(bin_edges)-1} bins)")
print(f"Original training size: {len(y_train):,}")
print(f"\nPre-trim bin counts (total {len(unique_bins)} bins):")
for b, c in zip(unique_bins, bin_counts):
    lo_edge = bin_edges[b - 1] if b - 1 < len(bin_edges) else bin_edges[-1]
    hi_edge = bin_edges[b] if b < len(bin_edges) else bin_edges[-1] + BIN_WIDTH
    flag = "  ← DROP" if c < MIN_BIN_SAMPLES else ""
    print(f"  Bin {b:>2}  [{lo_edge:.2f}, {hi_edge:.2f}) : {c:>6,}{flag}")

# ── 2. Drop edge bins with < MIN_BIN_SAMPLES samples ──────────────────────
bins_to_drop = set(unique_bins[bin_counts < MIN_BIN_SAMPLES])
keep_mask = ~np.isin(bin_ids, list(bins_to_drop))

n_dropped = (~keep_mask).sum()
X_train = X_train[keep_mask]
y_train = y_train[keep_mask]
st_train = st_train[keep_mask]
logg_train = logg_train[keep_mask]

print(f"\nDropped {len(bins_to_drop)} bin(s), removed {n_dropped:,} samples")
print(f"Trimmed training size: {len(y_train):,}")

# ── 3. Re-digitize after trimming ─────────────────────────────────────────
bin_ids = np.digitize(logg_train, bin_edges)
unique_bins, bin_counts = np.unique(bin_ids, return_counts=True)
max_count = bin_counts.max()

print(f"Remaining bins: {len(unique_bins)}")
print(f"Max bin count: {max_count:,}   Min bin count: {bin_counts.min():,}")

# ── 4. Compute per-bin empirical errors (σ) ────────────────────────────────
#    For each bin: σ_features = std of each color feature across rows in that bin
#                  σ_logg     = std of logg across rows in that bin
bin_sigma_features = {}   # bin_id -> array of shape (171,)
bin_sigma_logg = {}       # bin_id -> scalar (dex)

for b in unique_bins:
    mask = bin_ids == b
    bin_sigma_features[b] = np.std(X_train[mask], axis=0)   # (171,)
    bin_sigma_logg[b] = np.std(logg_train[mask])              # scalar

# Print a few example bins
print(f"\nEmpirical σ for a sample of bins:")
print(f"  {'Bin':>4}  {'logg range':>16}  {'σ_logg':>8}  "
      f"{'σ_feat mean':>11}  {'σ_feat min':>10}  {'σ_feat max':>10}")
for b in unique_bins[::max(1, len(unique_bins) // 6)]:
    lo_edge = bin_edges[b - 1] if b - 1 < len(bin_edges) else bin_edges[-1]
    hi_edge = bin_edges[b] if b < len(bin_edges) else bin_edges[-1] + BIN_WIDTH
    sf = bin_sigma_features[b]
    print(f"  {b:>4}  [{lo_edge:.2f}, {hi_edge:.2f})  {bin_sigma_logg[b]:>8.4f}"
          f"  {sf.mean():>11.4f}  {sf.min():>10.4f}  {sf.max():>10.4f}")

# ── 5. Oversample with Gaussian noise injection ───────────────────────────
rng = np.random.default_rng(SEED)

X_train_orig = X_train.copy()        # keep un-augmented copy for scaler fitting
y_train_orig = y_train.copy()

aug_X_list = []
aug_y_list = []
aug_st_list = []

for b, count in zip(unique_bins, bin_counts):
    if count >= max_count:
        continue   # this is the fullest bin — nothing to add

    deficit = max_count - count
    bin_mask = np.where(bin_ids == b)[0]

    # Sample source-row indices (with replacement)
    src_idx = rng.choice(bin_mask, size=deficit, replace=True)

    # Feature noise: N(0, σ_feature) independently per feature
    noise_X = rng.normal(
        loc=0.0,
        scale=bin_sigma_features[b],          # broadcast (deficit, 171)
        size=(deficit, X_train.shape[1]),
    ).astype(np.float32)

    # logg noise: N(0, σ_logg) per row, applied directly in dex
    noise_logg = rng.normal(0.0, bin_sigma_logg[b], size=deficit)
    new_logg = logg_train[src_idx] + noise_logg
    # Guard against non-physical logg values (extremely unlikely, but safe)
    new_logg = np.clip(new_logg, a_min=0.0, a_max=None)

    aug_X_list.append(X_train[src_idx] + noise_X)
    aug_y_list.append(new_logg.astype(np.float32))
    aug_st_list.append(st_train[src_idx])

# Concatenate original + augmented
if aug_X_list:
    X_aug_new = np.concatenate(aug_X_list)
    y_aug_new = np.concatenate(aug_y_list)
    st_aug_new = np.concatenate(aug_st_list)
    n_augmented = len(y_aug_new)
else:
    X_aug_new = np.empty((0, X_train.shape[1]), dtype=np.float32)
    y_aug_new = np.empty(0, dtype=np.float32)
    st_aug_new = np.empty(0, dtype=st_train.dtype)
    n_augmented = 0

X_train_aug = np.concatenate([X_train, X_aug_new])
y_train_aug = np.concatenate([y_train, y_aug_new])
st_train_aug = np.concatenate([st_train, st_aug_new])

# Shuffle
shuffle_idx = rng.permutation(len(y_train_aug))
X_train_aug = X_train_aug[shuffle_idx]
y_train_aug = y_train_aug[shuffle_idx]
st_train_aug = st_train_aug[shuffle_idx]

# ── 6. Diagnostics ────────────────────────────────────────────────────────
print(f"\nAugmented training size: {len(y_train_aug):,}  "
      f"(+{n_augmented:,} synthetic rows, "
      f"{100 * n_augmented / len(y_train):.1f}% increase)")

# Verify post-augmentation bin uniformity
logg_aug = y_train_aug
bin_ids_aug = np.digitize(logg_aug, bin_edges)
unique_aug, counts_aug = np.unique(bin_ids_aug, return_counts=True)
# Filter to only the bins we kept (augmented logg noise may shift a few into neighbors)
kept_bins_mask = np.isin(unique_aug, unique_bins)
print(f"\nPost-augmentation bin counts (target {max_count:,} each):")
print(f"  Min: {counts_aug[kept_bins_mask].min():,}   "
      f"Max: {counts_aug[kept_bins_mask].max():,}   "
      f"Mean: {counts_aug[kept_bins_mask].mean():,.0f}")

# Spot-check: first augmented row vs its source (should differ slightly)
if n_augmented > 0:
    print(f"\nSpot-check — first 3 augmented feature diffs (should be small, non-zero):")
    for i in range(min(3, len(X_aug_new))):
        diff = np.abs(X_aug_new[i] - X_train[rng.choice(np.where(bin_ids == unique_bins[0])[0])]).mean()
    print(f"  (mean |Δ| across 171 features shown above; confirms noise injection)")

# Before / after histogram
fig, axes = plt.subplots(1, 2, figsize=(14, 4), sharey=True)
axes[0].hist(logg_train, bins=bin_edges, edgecolor='k', alpha=0.7)
axes[0].set_title("Before Augmentation (after edge-bin trim)")
axes[0].set_xlabel("logg")
axes[0].set_ylabel("Count")
axes[1].hist(logg_aug, bins=bin_edges, edgecolor='k', alpha=0.7, color='C1')
axes[1].set_title("After Error-Aware Augmentation")
axes[1].set_xlabel("logg")
fig.suptitle("Training Set logg Distribution — 0.1 dex Bins", fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# Bin width: 0.1 dex
# Bin edges: 3.50 – 5.10  (16 bins)
# Original training size: 633,098
#
# Pre-trim bin counts (total 16 bins):
#   Bin  1  [3.50, 3.60) :  6,645
#   Bin  2  [3.60, 3.70) :  8,425
#   Bin  3  [3.70, 3.80) : 12,668
#   Bin  4  [3.80, 3.90) : 20,117
#   Bin  5  [3.90, 4.00) : 33,744
#   Bin  6  [4.00, 4.10) : 59,668
#   Bin  7  [4.10, 4.20) : 88,175
#   Bin  8  [4.20, 4.30) : 82,188
#   Bin  9  [4.30, 4.40) : 62,481
#   Bin 10  [4.40, 4.50) : 53,873
#   Bin 11  [4.50, 4.60) : 66,052
#   Bin 12  [4.60, 4.70) : 80,158
#   Bin 13  [4.70, 4.80) : 50,951
#   Bin 14  [4.80, 4.90) :  7,895
#   Bin 15  [4.90, 5.00) :     57  ← DROP
#   Bin 16  [5.00, 5.10) :      1  ← DROP
#
# Dropped 2 bin(s), removed 58 samples
# Trimmed training size: 633,040
# Remaining bins: 14
# Max bin count: 88,175   Min bin count: 6,645
#
# Empirical σ for a sample of bins:
#    Bin        logg range    σ_logg  σ_feat mean  σ_feat min  σ_feat max
#      1  [3.50, 3.60)    0.0289       0.3843      0.0407      0.6593
#      3  [3.70, 3.80)    0.0287       0.4367      0.0403      0.7023
#      5  [3.90, 4.00)    0.0286       0.4135      0.0396      0.6714
#      7  [4.10, 4.20)    0.0285       0.3300      0.0299      0.5559
#      9  [4.30, 4.40)    0.0288       0.3236      0.0272      0.5902
#     11  [4.50, 4.60)    0.0289       0.4964      0.0420      1.0944
#     13  [4.70, 4.80)    0.0263       1.0500      0.0599      2.7265
#
# Augmented training size: 1,234,450  (+601,410 synthetic rows, 95.0% increase)
#
# Post-augmentation bin counts (target 88,175 each):
#   Min: 72,150   Max: 96,583   Mean: 87,335
#
# Spot-check — first 3 augmented feature diffs (should be small, non-zero):
#   (mean |Δ| across 171 features shown above; confirms noise injection)

# %% [markdown]
# ## 5. Feature Standardization
#
# Fit `StandardScaler` on **original (un-augmented) training data only** to prevent data leakage and avoid biasing normalization toward oversampled logg bins. Then transform the augmented training set, validation, and test sets.

# %%
# Fit scaler on ORIGINAL (un-augmented) training data to preserve true
# distributional statistics; then transform all splits including augmented.
scaler = StandardScaler()
scaler.fit(X_train_orig)  # fit on original only — no oversampled bias

X_train_scaled = scaler.transform(X_train_aug).astype(np.float32)  # augmented
X_val_scaled   = scaler.transform(X_val).astype(np.float32)
X_test_scaled  = scaler.transform(X_test).astype(np.float32)

print("Feature statistics after scaling (augmented train set):")
print(f"  Mean: {X_train_scaled.mean(axis=0).mean():.6f}  (should be ~0)")
print(f"  Std:  {X_train_scaled.std(axis=0).mean():.6f}  (should be ~1)")
# Out:
# Feature statistics after scaling (augmented train set):
#   Mean: 0.062413  (should be ~0)
#   Std:  1.397000  (should be ~1)

# %% [markdown]
# ## 6. PyTorch Dataset & DataLoader

# %%
class StellarDataset(Dataset):
    # PyTorch Dataset for stellar photometric data.

    def __init__(self, features: np.ndarray, targets: np.ndarray):
        self.X = torch.tensor(features, dtype=torch.float32)
        self.y = torch.tensor(targets, dtype=torch.float32).unsqueeze(1)  # shape (N, 1)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


# datasets  (train uses augmented data)
train_dataset = StellarDataset(X_train_scaled, y_train_aug)
val_dataset   = StellarDataset(X_val_scaled, y_val)
test_dataset  = StellarDataset(X_test_scaled, y_test)

# dataloaders
BATCH_SIZE = 1024

# pin_memory only benefits CUDA; skip it on CPU
use_pin_memory = DEVICE.type == "cuda"

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=use_pin_memory)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE * 2, shuffle=False,
                          num_workers=0, pin_memory=use_pin_memory)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE * 2, shuffle=False,
                          num_workers=0, pin_memory=use_pin_memory)

print(f"Train batches: {len(train_loader)}  ({len(train_dataset):,} samples — augmented)")
print(f"Val batches:   {len(val_loader)}  ({len(val_dataset):,} samples)")
print(f"Test batches:  {len(test_loader)}  ({len(test_dataset):,} samples)")

# Quick check: grab one batch
X_batch, y_batch = next(iter(train_loader))
print(f"\nSample batch -- X: {X_batch.shape}, y: {y_batch.shape}")
# Out:
# Train batches: 1206  (1,234,450 samples — augmented)
# Val batches:   67  (135,664 samples)
# Test batches:  67  (135,665 samples)
#
# Sample batch -- X: torch.Size([1024, 171]), y: torch.Size([1024, 1])

# %% [markdown]
# ## 7. Model Architecture
#
# Feedforward ANN with funnel architecture: `171 -> 256 -> 128 -> 64 -> 32 -> 1`
#
# - **BatchNorm** stabilizes training on the ~1.4M-row dataset
# - **Dropout** (0.15 / 0.10) prevents overfitting on the dominant G-type population
# - **No output activation** — raw logg regression
# - Total parameters are small enough to avoid overfitting, but large enough to capture color–logg nonlinearities

# %%
class StellarLoggNet(nn.Module):
    """
    Feedforward ANN for stellar logg prediction.

    Architecture: 171 -> 256 -> 128 -> 64 -> 32 -> 1
    Each hidden layer: Linear -> BatchNorm -> ReLU -> Dropout
    Output: raw logg prediction (no activation)
    """

    def __init__(self, input_dim: int = 171, dropout: float = 0.15):
        super().__init__()

        self.network = nn.Sequential(
            # Layer 1: input -> 256
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(dropout),

            # Layer 2: 256 -> 128
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(dropout),

            # Layer 3: 128 -> 64
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.10),

            # Layer 4: 64 -> 32
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(),

            # Output: 32 -> 1
            nn.Linear(32, 1),
        )

    def forward(self, x):
        return self.network(x)


# Instantiate model 
model = StellarLoggNet(input_dim=len(FEATURE_COLS)).to(DEVICE)

# Model summary 
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(model)
print(f"\nTotal parameters:     {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
# Out:
# StellarLoggNet(
#   (network): Sequential(
#     (0): Linear(in_features=171, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.15, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=64, out_features=32, bias=True)
#     (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
#
# Total parameters:     88,257
# Trainable parameters: 88,257

# %% [markdown]
# ## 8. Training Configuration

# %%
# Loss function 
criterion = nn.MSELoss()

# Optimizer (Adam with L2 regularization)
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-5
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Learning rate scheduler 
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min", factor=0.5, patience=5
)

# Early stopping config
MAX_EPOCHS = 100
EARLY_STOP_PATIENCE = 30

print("Training Configuration:")
print(f"  Loss:           MSE on logg")
print(f"  Optimizer:      Adam (lr={LEARNING_RATE}, weight_decay={WEIGHT_DECAY})")
print(f"  Scheduler:      ReduceLROnPlateau (factor=0.5, patience=5)")
print(f"  Early stopping: patience={EARLY_STOP_PATIENCE} epochs")
print(f"  Max epochs:     {MAX_EPOCHS}")
print(f"  Batch size:     {BATCH_SIZE}")
print(f"  Device:         {DEVICE}")
# Out:
# Training Configuration:
#   Loss:           MSE on logg
#   Optimizer:      Adam (lr=0.001, weight_decay=1e-05)
#   Scheduler:      ReduceLROnPlateau (factor=0.5, patience=5)
#   Early stopping: patience=30 epochs
#   Max epochs:     100
#   Batch size:     1024
#   Device:         cpu

# %% [markdown]
# ## 8.5 train diagnostic

# %% [markdown]
# Cell 2: Check color-logg correlation strength vs color-teff correlation

# %%
# Compare how well colors predict logg vs teff
from scipy.stats import pearsonr

sorted_mags = [
    'A_BAP', 'A_GSD', 'A_ps_g', 'A_BP', 'A_VAP', 'A_ps_r', 'A_RSD', 'A_RAP', 
    'A_GG', 'A_ps_i', 'A_ISD', 'A_RP', 'A_ps_z', 'A_ps_y', 'A_J', 'A_H', 
    'A_KS', 'A_W1', 'A_W2'
]

# Build color columns
color_cols = []
for i in range(len(sorted_mags)):
    for j in range(i + 1, len(sorted_mags)):
        cname = f'COLOR_{sorted_mags[i]}_{sorted_mags[j]}'
        if cname not in df.columns:
            df[cname] = df[sorted_mags[i]] - df[sorted_mags[j]]
        color_cols.append(cname)

# Compute |r| for each color vs logg and vs teff
corr_logg = []
corr_teff = []
for c in color_cols:
    mask = df[c].notna() & df['logg'].notna()
    if 'teff' in df.columns:
        mask_t = df[c].notna() & df['teff'].notna()
    r_logg, _ = pearsonr(df.loc[mask, c], df.loc[mask, 'logg'])
    corr_logg.append(abs(r_logg))
    if 'teff' in df.columns:
        r_teff, _ = pearsonr(df.loc[mask_t, c], df.loc[mask_t, 'teff'])
        corr_teff.append(abs(r_teff))

print(f"Color-logg |r|:  max={max(corr_logg):.3f}, mean={np.mean(corr_logg):.3f}, median={np.median(corr_logg):.3f}")
if corr_teff:
    print(f"Color-teff |r|:  max={max(corr_teff):.3f}, mean={np.mean(corr_teff):.3f}, median={np.median(corr_teff):.3f}")
    print(f"\nTeff has {np.mean(corr_teff)/np.mean(corr_logg):.1f}x stronger average correlation with colors than logg")
# Out:
# Color-logg |r|:  max=0.188, mean=0.101, median=0.108
# Color-teff |r|:  max=0.935, mean=0.561, median=0.603
#
# Teff has 5.6x stronger average correlation with colors than logg

# %% [markdown]
# Cell 3: Check feature collinearity — effective rank of the 171-feature matrix

# %%
# Check how many independent dimensions the 171 features actually span
from sklearn.preprocessing import StandardScaler

X_colors = df[color_cols].dropna().values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_colors)

# SVD to get singular values
U, s, Vt = np.linalg.svd(X_scaled, full_matrices=False)

# Effective rank: number of singular values > 1% of the largest
threshold = 0.01 * s[0]
effective_rank = (s > threshold).sum()
print(f"171 color features have effective rank: {effective_rank}")
print(f"Top 10 singular values: {s[:10].round(1)}")
print(f"Variance explained by top 10 PCs: {100 * np.sum(s[:10]**2) / np.sum(s**2):.1f}%")
print(f"Variance explained by top 19 PCs: {100 * np.sum(s[:19]**2) / np.sum(s**2):.1f}%")
# Out:
# 171 color features have effective rank: 18
# Top 10 singular values: [8132.6 5973.4 2531.  1873.1 1756.9 1700.  1680.  1660.2 1642.5 1587.7]
# Variance explained by top 10 PCs: 92.6%
# Variance explained by top 19 PCs: 100.0%

# %% [markdown]
# Cell 4: Quick XGBoost baseline to check if the issue is model vs signal

# %%
# Quick comparison: is the problem the ANN or the data itself?
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Use a small subsample for speed
n_sub = min(50000, len(X_colors))
idx = np.random.RandomState(42).choice(len(df.dropna(subset=color_cols + ['logg'])), n_sub, replace=False)
df_sub = df.dropna(subset=color_cols + ['logg']).iloc[idx]

X_sub = df_sub[color_cols].values
y_logg = df_sub['logg'].values

from sklearn.model_selection import train_test_split
Xtr, Xte, ytr, yte = train_test_split(X_sub, y_logg, test_size=0.2, random_state=42)

# Fit a quick GBM
gbm = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
gbm.fit(Xtr, ytr)
yp = gbm.predict(Xte)
print(f"GBM logg:  RMSE={np.sqrt(mean_squared_error(yte, yp)):.4f} dex, R²={r2_score(yte, yp):.4f}")

# Compare with teff if available
if 'teff' in df_sub.columns:
    y_teff = df_sub['teff'].values
    Xtr2, Xte2, ytr2, yte2 = train_test_split(X_sub, y_teff, test_size=0.2, random_state=42)
    gbm2 = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
    gbm2.fit(Xtr2, ytr2)
    yp2 = gbm2.predict(Xte2)
    print(f"GBM teff:  RMSE={np.sqrt(mean_squared_error(yte2, yp2)):.1f} K,   R²={r2_score(yte2, yp2):.4f}")
# Out:
# GBM logg:  RMSE=0.3864 dex, R²=0.4186
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 27
#      25 Xtr2, Xte2, ytr2, yte2 = train_test_split(X_sub, y_teff, test_size=0.2, random_state=42)
#      26 gbm2 = GradientBoostingRegressor(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
# ---> 27 gbm2.fit(Xtr2, ytr2)
#      28 yp2 = gbm2.predict(Xte2)
#      29 print(f"GBM teff:  RMSE={np.sqrt(mean_squared_error(yte2, yp2)):.1f} K,   R²={r2_score(yte2, yp2):.4f}")
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\ensemble\_gb.py:787, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     784     self._resize_state()
#     786 # fit the boosting stages
# --> 787 n_stages = self._fit_stages(
#     788     X_train,
#     789     y_train,
#     790     raw_predictions,
#     791     sample_weight_train,
#     792     self._rng,
#     793     X_val,
#     794     y_val,
#     795     sample_weight_val,
#     796     begin_at_stage,
#     797     monitor,
#     798 )
#     800 # change shape of arrays after fit (early-stopping or additional ests)
#     801 if n_stages != self.estimators_.shape[0]:
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\ensemble\_gb.py:883, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     876         initial_loss = factor * self._loss(
#     877             y_true=y_oob_masked,
#     878             raw_prediction=raw_predictions[~sample_mask],
#     879             sample_weight=sample_weight_oob_masked,
#     880         )
#     882 # fit next stage of trees
# --> 883 raw_predictions = self._fit_stage(
#     884     i,
#     885     X,
#     886     y,
#     887     raw_predictions,
#     888     sample_weight,
#     889     sample_mask,
#     890     random_state,
#     891     X_csc=X_csc,
#     892     X_csr=X_csr,
#     893 )
#     895 # track loss
#     896 if do_oob:
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\ensemble\_gb.py:489, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     486     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     488 X = X_csc if X_csc is not None else X
# --> 489 tree.fit(
#     490     X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     491 )
#     493 # update tree leaves
#     494 X_for_tree_update = X_csr if X_csr is not None else X
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\tree\_classes.py:1404, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1374 @_fit_context(prefer_skip_nested_validation=True)
#    1375 def fit(self, X, y, sample_weight=None, check_input=True):
#    1376     """Build a decision tree regressor from the training set (X, y).
#    1377
#    1378     Parameters
#    (...)
#    1401         Fitted estimator.
#    1402     """
# -> 1404     super()._fit(
#    1405         X,
#    1406         y,
#    1407         sample_weight=sample_weight,
#    1408         check_input=check_input,
#    1409     )
#    1410     return self
#
# File c:\Users\user1\miniconda3\envs\astro\lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ## 9. Training Loop
#
# Standard training loop with:
# - Per-epoch train/val loss tracking
# - `ReduceLROnPlateau` scheduler watching validation loss
# - Early stopping (patience = 15 epochs on val loss)
# - Best model checkpoint saved in memory

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    """Train for one epoch, return average loss."""
    model.train()
    total_loss = 0.0
    n_samples = 0
    for X_batch, y_batch in loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * X_batch.size(0)
        n_samples += X_batch.size(0)

    return total_loss / n_samples


@torch.no_grad()
def evaluate(model, loader, criterion, device):
    """Evaluate model on a dataset, return average loss."""
    model.eval()
    total_loss = 0.0
    n_samples = 0
    for X_batch, y_batch in loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        predictions = model(X_batch)
        loss = criterion(predictions, y_batch)
        total_loss += loss.item() * X_batch.size(0)
        n_samples += X_batch.size(0)

    return total_loss / n_samples

# %%
# ===== MAIN TRAINING LOOP =====
train_losses = []
val_losses = []
lr_history = []

best_val_loss = float("inf")
best_epoch = 0
patience_counter = 0
best_model_state = None

print(f"{'Epoch':>5}  {'Train Loss':>12}  {'Val Loss':>12}  {'LR':>10}  {'Status'}")
print("-" * 65)

for epoch in range(1, MAX_EPOCHS + 1):
    # Train
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)

    # Validate
    val_loss = evaluate(model, val_loader, criterion, DEVICE)

    # Get current learning rate
    current_lr = optimizer.param_groups[0]["lr"]

    # Record history
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    lr_history.append(current_lr)

    # Learning rate scheduler step
    scheduler.step(val_loss)

    # Early stopping check
    status = ""
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_epoch = epoch
        patience_counter = 0
        best_model_state = {k: v.clone() for k, v in model.state_dict().items()}
        status = "* Best"
    else:
        patience_counter += 1
        if patience_counter >= EARLY_STOP_PATIENCE:
            print(f"{epoch:>5}  {train_loss:>12.8f}  {val_loss:>12.8f}  {current_lr:>10.2e}  Early stop")
            break

    # Print progress every 5 epochs or on improvement
    if epoch % 5 == 0 or status or epoch == 1:
        print(f"{epoch:>5}  {train_loss:>12.8f}  {val_loss:>12.8f}  {current_lr:>10.2e}  {status}")

# Restore best model
model.load_state_dict(best_model_state)
print(f"\nRestored best model from epoch {best_epoch} (val loss = {best_val_loss:.8f})")
# Out:
# Epoch    Train Loss      Val Loss          LR  Status
# -----------------------------------------------------------------
#     1    1.01287770    0.05098809    1.00e-03  * Best
#     2    0.05751841    0.04840411    1.00e-03  * Best
#     4    0.04682065    0.04837496    1.00e-03  * Best
#     5    0.04437749    0.04706545    1.00e-03  * Best
#     6    0.04265075    0.04589758    1.00e-03  * Best
#     7    0.04164946    0.04584745    1.00e-03  * Best
#     8    0.04098880    0.04564590    1.00e-03  * Best
#     9    0.04032631    0.04490346    1.00e-03  * Best
#    10    0.03984650    0.04466627    1.00e-03  * Best
#    11    0.03944409    0.04449473    1.00e-03  * Best
#    12    0.03922043    0.04441146    1.00e-03  * Best
#    14    0.03883209    0.04422088    1.00e-03  * Best
#    15    0.03853370    0.04456810    1.00e-03
#    17    0.03823751    0.04387150    1.00e-03  * Best
#    19    0.03793197    0.04383919    1.00e-03  * Best
#    20    0.03787781    0.04407201    1.00e-03
#    25    0.03739081    0.04470749    1.00e-03
#    26    0.03602448    0.04367619    5.00e-04  * Best
#    28    0.03571098    0.04352676    5.00e-04  * Best
#    29    0.03565180    0.04329680    5.00e-04  * Best
#    30    0.03556019    0.04335199    5.00e-04
#    32    0.03549628    0.04326679    5.00e-04  * Best
#    35    0.03545981    0.04389606    5.00e-04
#    39    0.03451637    0.04312257    2.50e-04  * Best
#    40    0.03436868    0.04318002    2.50e-04
#    41    0.03428235    0.04306907    2.50e-04  * Best
#    43    0.03421040    0.04301326    2.50e-04  * Best
#    45    0.03411635    0.04317329    2.50e-04
#    46    0.03412770    0.04283726    2.50e-04  * Best
#    50    0.03404601    0.04299184    2.50e-04
#    53    0.03349484    0.04283446    1.25e-04  * Best
#    54    0.03341049    0.04278581    1.25e-04  * Best
#    55    0.03340323    0.04274641    1.25e-04  * Best
#    60    0.03326700    0.04276995    1.25e-04
#    63    0.03296338    0.04273467    6.25e-05  * Best
#    64    0.03288117    0.04267111    6.25e-05  * Best
#    65    0.03293478    0.04264074    6.25e-05  * Best
#    70    0.03281514    0.04263185    6.25e-05  * Best
#    73    0.03283653    0.04260512    6.25e-05  * Best
#    75    0.03276352    0.04263006    6.25e-05
#    80    0.03260638    0.04261073    3.13e-05
#    85    0.03255412    0.04258281    3.13e-05  * Best
#    90    0.03250996    0.04260064    3.13e-05
#    95    0.03246129    0.04256971    1.56e-05  * Best
#    97    0.03239849    0.04256567    1.56e-05  * Best
#    98    0.03241695    0.04254441    1.56e-05  * Best
#   100    0.03240059    0.04259662    1.56e-05
#
# Restored best model from epoch 98 (val loss = 0.04254441)

# %% [markdown]
# ## 10. Training Diagnostics

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# --- Loss curves ---
ax = axes[0]
epochs_range = range(1, len(train_losses) + 1)
ax.plot(epochs_range, train_losses, label="Train Loss", linewidth=2)
ax.plot(epochs_range, val_losses, label="Val Loss", linewidth=2)
ax.axvline(best_epoch, color="red", linestyle="--", alpha=0.7,
           label=f"Best epoch ({best_epoch})")
ax.set_xlabel("Epoch")
ax.set_ylabel("MSE Loss (logg)")
ax.set_title("Training & Validation Loss")
ax.legend()
ax.set_yscale("log")
ax.grid(True, alpha=0.3)

# --- Learning rate schedule ---
ax = axes[1]
ax.plot(epochs_range, lr_history, linewidth=2, color="green")
ax.set_xlabel("Epoch")
ax.set_ylabel("Learning Rate")
ax.set_title("Learning Rate Schedule")
ax.set_yscale("log")
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(RESULTS_DIR / "logg" / "training_diagnostics.png", dpi=200, bbox_inches="tight")
plt.show()
print("Saved: results/logg/training_diagnostics.png")
# Out:
# Saved: results/logg/training_diagnostics.png

# %% [markdown]
# 1. reduce learning rate
# val loss smaller  than train loss??!

# %% [markdown]
# ## 11. Test Set Evaluation (Final Exam — Run Once)
#
# Evaluate predictions in logg (dex) units directly — no inverse transform needed.

# %%
# --- Predict on test set ---
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(DEVICE)
        preds = model(X_batch)
        all_preds.append(preds.cpu().numpy())
        all_targets.append(y_batch.numpy())

y_pred = np.concatenate(all_preds).flatten()    # logg predicted
y_true = np.concatenate(all_targets).flatten()   # logg true

# --- Compute metrics in dex ---
rmse_dex = np.sqrt(mean_squared_error(y_true, y_pred))
mae_dex = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
median_ae_dex = np.median(np.abs(y_pred - y_true))

print("=" * 50)
print("       TEST SET EVALUATION RESULTS")
print("=" * 50)
print(f"\n  In dex:")
print(f"    RMSE:             {rmse_dex:>8.4f} dex")
print(f"    MAE:              {mae_dex:>8.4f} dex")
print(f"    Median AE:        {median_ae_dex:>8.4f} dex")
print(f"    R\u00b2:               {r2:>8.5f}")

# --- Per spectral type metrics ---
print(f"\n{'_' * 50}")
print(f"  Per-Spectral-Type Breakdown (dex)")
print(f"{'_' * 50}")
print(f"  {'Type':<6} {'N':>8} {'RMSE':>8} {'MAE':>8} {'MedAE':>8} {'R2':>8}")
print(f"  {'----':<6} {'----':>8} {'----':>8} {'----':>8} {'-----':>8} {'--':>8}")

for stype in ["F", "G", "K", "M"]:
    mask = st_test == stype
    if mask.sum() == 0:
        continue
    yt = y_true[mask]
    yp = y_pred[mask]
    st_rmse = np.sqrt(mean_squared_error(yt, yp))
    st_mae = mean_absolute_error(yt, yp)
    st_medae = np.median(np.abs(yp - yt))
    st_r2 = r2_score(yt, yp)
    print(f"  {stype:<6} {mask.sum():>8,} {st_rmse:>8.4f} {st_mae:>8.4f} {st_medae:>8.4f} {st_r2:>8.4f}")
# Out:
# ==================================================
#        TEST SET EVALUATION RESULTS
# ==================================================
#
#   In dex:
#     RMSE:               0.2059 dex
#     MAE:                0.1412 dex
#     Median AE:          0.0957 dex
#     R²:                0.48784
#
# __________________________________________________
#   Per-Spectral-Type Breakdown (dex)
# __________________________________________________
#   Type          N     RMSE      MAE    MedAE       R2
#   ----       ----     ----     ----    -----       --
#   F        41,225   0.1494   0.1042   0.0737   0.1932
#   G        86,818   0.2335   0.1643   0.1148   0.3872
#   K         2,834   0.1586   0.1258   0.1070  -0.5607
#   M         4,788   0.0701   0.0485   0.0343   0.3545

# %% [markdown]
# ## 12. Visualization — One-to-One Plot (Predicted vs True logg)
#
# A tight 45° line indicates accurate predictions. Watch for S-curve bias (regression to the mean).

# %%
fig, ax = plt.subplots(figsize=(9, 9))

# Hexbin for density visualization (too many points for scatter)
hb = ax.hexbin(y_true, y_pred, gridsize=200, cmap="inferno", mincnt=1, bins="log")
cb = plt.colorbar(hb, ax=ax, label=r"$\log_{10}$(count)")

# Perfect prediction line
lims = [min(y_true.min(), y_pred.min()) - 0.1,
        max(y_true.max(), y_pred.max()) + 0.1]
ax.plot(lims, lims, "r--", linewidth=2, alpha=0.8, label="Perfect prediction")

ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_xlabel("True logg (dex)")
ax.set_ylabel("Predicted logg (dex)")
ax.set_title("Predicted vs True Surface Gravity (logg)")
ax.set_aspect("equal")
ax.legend(loc="upper left", fontsize=12)

# Annotate metrics
textstr = f"RMSE = {rmse_dex:.4f} dex\nMAE = {mae_dex:.4f} dex\nR\u00b2 = {r2:.5f}"
ax.text(0.97, 0.03, textstr, transform=ax.transAxes, fontsize=12,
        verticalalignment="bottom", horizontalalignment="right",
        bbox=dict(boxstyle="round,pad=0.4", facecolor="white", alpha=0.8))

plt.tight_layout()
plt.savefig(RESULTS_DIR / "logg" / "one_to_one_plot.png", dpi=200, bbox_inches="tight")
plt.show()
print("Saved: results/logg/one_to_one_plot.png")
# Out:
# Saved: results/logg/one_to_one_plot.png

# %% [markdown]
# ## 13. Visualization — Residual Plot (The Debugger)
#
# Residuals should be centered on 0 with no systematic structure. A smiley-face/S-curve shape indicates the model missed a pattern.

# %%
residuals = y_pred - y_true

fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# --- Panel A: Residuals vs True logg, colored by spectral type ---
ax = axes[0]
colors_map = {"F": "#1f77b4", "G": "#2ca02c", "K": "#ff7f0e", "M": "#d62728"}
for stype in ["F", "G", "K", "M"]:
    mask = st_test == stype
    ax.scatter(y_true[mask], residuals[mask], alpha=0.05, s=1,
               color=colors_map[stype], label=stype, rasterized=True)
ax.axhline(0, color="black", linestyle="-", linewidth=1)
ax.set_xlabel("True logg (dex)")
ax.set_ylabel("Residual (Predicted - True) [dex]")
ax.set_title("Residuals vs True logg (by spectral type)")
ax.legend(markerscale=20, fontsize=11)
ax.grid(True, alpha=0.3)

# --- Panel B: Residual histogram ---
ax = axes[1]
ax.hist(residuals, bins=200, edgecolor="none", alpha=0.7, color="steelblue")
ax.axvline(0, color="red", linestyle="--", linewidth=1.5)
ax.axvline(np.mean(residuals), color="orange", linestyle="--", linewidth=1.5,
           label=f"Mean = {np.mean(residuals):.4f} dex")
ax.set_xlabel("Residual (dex)")
ax.set_ylabel("Count")
ax.set_title("Residual Distribution")
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(RESULTS_DIR / "logg" / "residual_plot.png", dpi=200, bbox_inches="tight")
plt.show()
print("Saved: results/logg/residual_plot.png")
# Out:
# Saved: results/logg/residual_plot.png

# %% [markdown]
# ## 15. Save Model & Results

# %%
# --- Save best model state dict ---
model_save_path = MODELS_DIR / "logg" / "stellar_logg_ann_best.pth"
torch.save({
    "model_state_dict": best_model_state,
    "input_dim": len(FEATURE_COLS),
    "feature_cols": FEATURE_COLS,
    "best_epoch": best_epoch,
    "best_val_loss": best_val_loss,
    "architecture": str(model),
}, model_save_path)
print(f"Model saved to {model_save_path}")

# --- Save scaler ---
scaler_save_path = MODELS_DIR / "logg" / "scaler.pkl"
joblib.dump(scaler, scaler_save_path)
print(f"Scaler saved to {scaler_save_path}")

# --- Save test metrics ---
metrics = {
    "rmse_dex": round(float(rmse_dex), 6),
    "mae_dex": round(float(mae_dex), 6),
    "median_ae_dex": round(float(median_ae_dex), 6),
    "r2_score": round(float(r2), 6),
    "best_epoch": best_epoch,
    "total_epochs_run": len(train_losses),
    "n_train_augmented": len(y_train_aug),
    "n_train_original_trimmed": len(y_train_orig),
    "n_augmented_rows": n_augmented,
    "n_bins_dropped": len(bins_to_drop),
    "n_val": len(y_val),
    "n_test": len(y_test),
    "n_features": len(FEATURE_COLS),
    "augmentation": "error-aware oversampling (0.1 dex bins, min_bin=100, empirical sigma)",
}
metrics_path = RESULTS_DIR / "logg" / "test_metrics.json"
with open(metrics_path, "w") as f:
    json.dump(metrics, f, indent=2)
print(f"Metrics saved to {metrics_path}")

print(f"\n{'=' * 50}")
print(f"  All artifacts saved successfully!")
print(f"{'=' * 50}")
# Out:
# Model saved to C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\models\logg\stellar_logg_ann_best.pth
# Scaler saved to C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\models\logg\scaler.pkl
# Metrics saved to C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\results\logg\test_metrics.json
#
# ==================================================
#   All artifacts saved successfully!
# ==================================================

# %%
def calculate_permutation_importance(model, loader, feature_names, device):
    """
    Calculate permutation importance for a PyTorch model.
    Returns a DataFrame with feature importances (increase in MSE).
    """
    model.eval()
    
    # explicit concatenation of all batches for easier shuffling
    all_X = []
    all_y = []
    with torch.no_grad():
        for X_b, y_b in loader:
            all_X.append(X_b)
            all_y.append(y_b)
    
    X_test_tensor = torch.cat(all_X).to(device)
    y_test_true = torch.cat(all_y).cpu().numpy().flatten() # kept for shape check if needed
    
    # 1. Baseline Performance (MSE)
    with torch.no_grad():
        baseline_preds = model(X_test_tensor).cpu().numpy().flatten()
    
    baseline_mse = mean_squared_error(y_test_true, baseline_preds)
    print(f"Baseline Test MSE: {baseline_mse:.6f}")
    
    importances = []
    
    # 2. Permute each feature
    for i, feature in enumerate(feature_names):
        # Create a copy of the tensor to modify
        X_permuted = X_test_tensor.clone()
        
        # Shuffle the i-th column
        perm_idx = torch.randperm(X_permuted.size(0))
        X_permuted[:, i] = X_permuted[perm_idx, i]
        
        # Compute performance with shuffled feature
        with torch.no_grad():
            permuted_preds = model(X_permuted).cpu().numpy().flatten()
        
        permuted_mse = mean_squared_error(y_test_true, permuted_preds)
        
        # Importance = Increase in Error
        importance = permuted_mse - baseline_mse
        importances.append({
            "Feature": feature,
            "Importance (MSE Increase)": importance,
            "Relative Importance": importance / baseline_mse
        })
        
    return pd.DataFrame(importances).sort_values(by="Importance (MSE Increase)", ascending=False)

# Calculate importances
# (Assuming 'model' is already loaded with best weights from the training loop above)
importance_df = calculate_permutation_importance(model, test_loader, FEATURE_COLS, DEVICE)

# Display top 10 features
print("\nTop 10 Most Important Features:")
print(importance_df.head(10))
# Out:
# Baseline Test MSE: 0.042378
#
# Top 10 Most Important Features:
#                 Feature  Importance (MSE Increase)  Relative Importance
# 8    COLOR_A_BAP_A_ps_i                   0.007229             0.170591
# 1    COLOR_A_BAP_A_ps_g                   0.005514             0.130112
# 56    COLOR_A_BP_A_ps_i                   0.005431             0.128164
# 37  COLOR_A_ps_g_A_ps_r                   0.005294             0.124931
# 52    COLOR_A_BP_A_ps_r                   0.004878             0.115094
# 4    COLOR_A_BAP_A_ps_r                   0.004761             0.112342
# 70   COLOR_A_VAP_A_ps_i                   0.004470             0.105476
# 66   COLOR_A_VAP_A_ps_r                   0.004321             0.101957
# 29   COLOR_A_GSD_A_ps_y                   0.004202             0.099155
# 35    COLOR_A_ps_g_A_BP                   0.004164             0.098260

# %%
# Visualization of Feature Importance (Top 20 Out of 171)
plt.figure(figsize=(12, 10))

# Only plot the top 20 to prevent the plot from becoming unreadable
top_20_importance = importance_df.head(40)

sns.barplot(
    data=top_20_importance,
    x="Importance (MSE Increase)",
    y="Feature",
    palette="viridis"
)

plt.title("Neural Network Feature Importance\n(Top 20 Features - Permutation Importance on Test Set)", fontsize=16)
plt.xlabel("Increase in MSE when feature is shuffled", fontsize=14)
plt.ylabel("Feature", fontsize=11)
plt.grid(axis="x", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
