# %% [markdown]
# # Consolidated Color vs logg Analysis for F, G, K, M Dwarfs
#
# This notebook provides a unified analysis of the color-logg relationships across multiple spectral types (F, G, K, M). It generates large-scale contour plots showing the density of stars in various color spaces relative to their surface gravity (logg).

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_context("talk")
sns.set_palette("husl")

# Define paths
DATA_DIR = Path(r'C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\data\outlier_filtering_results')
RESULTS_DIR = Path(r'C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\results\consolidated_analysis')
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Phase 1: Data Loading (Sanity Check)
#
# We will load datasets for F, G, K, and M dwarfs and combine them.

# %%
def load_consolidated_data(data_dir):
    spectral_types = ['F', 'G', 'K', 'M']
    dfs = []
    
    for stype in spectral_types:
        file_path = data_dir / f'Xmatch_gaia_LAMOST_LAMOSTvac_{stype}_dwarfs_logg_clean.csv'
        if file_path.exists():
            temp_df = pd.read_csv(file_path)
            temp_df['spectral_type_group'] = stype
            dfs.append(temp_df)
            print(f"Loaded {stype} dwarf data: {len(temp_df)} rows")
        else:
            print(f"Warning: {file_path} not found.")
    
    combined_df = pd.concat(dfs, ignore_index=True)
    print(f"\nTotal combined rows: {len(combined_df)}")
    return combined_df

# Initial load (Sanity Check 1)
df = load_consolidated_data(DATA_DIR)

print(f"logg range: {df['logg'].min():.2f} to {df['logg'].max():.2f}")
# Out:
# Loaded F dwarf data: 274831 rows
# Loaded G dwarf data: 840391 rows
# Loaded K dwarf data: 160604 rows
# Loaded M dwarf data: 31938 rows
#
# Total combined rows: 1307764
# logg range: 3.50 to 5.02

# %% [markdown]
# ### Drop rows with double spectral type label

# %%
# Filter for rows where the 'obsid' appears more than once
overlap_mask = df.duplicated(subset=['obsid'], keep=False)
overlapping_stars_df = df[overlap_mask].sort_values(by=['obsid', 'spectral_type_group'])

# summary table of the overlaps
if not overlapping_stars_df.empty:
    # Group by obsid to find which spectral types each star belongs to
    star_overlap_types = overlapping_stars_df.groupby('obsid')['spectral_type_group'].apply(lambda x: ' & '.join(sorted(x.unique())))
    
    overlap_summary = star_overlap_types.value_counts().reset_index()
    overlap_summary.columns = ['Spectral Type Combination', 'Star Count']
    
    print("\n=== Overlap Summary Table ===")
    display(overlap_summary)
    
    print(f"\nTotal overlapping rows: {len(overlapping_stars_df)}")
    print(f"Total unique overlapping stars: {len(star_overlap_types)}")
    
    print("\n=== DataFrame of Overlapping Stars (First 5 rows) ===")
    display(overlapping_stars_df.head())
else:
    print("No overlapping stars found based on 'obsid'.")
# Out:
# === Overlap Summary Table ===
#   Spectral Type Combination  Star Count
# 0                     F & G      261605
# 1                     G & K      141715
# 2                     G & M          17
# Total overlapping rows: 806674
# Total unique overlapping stars: 403337
#
# === DataFrame of Overlapping Stars (First 5 rows) ===
#           obsid subclass       gaia_source_id  distance_gaia_pc     teff  \
# 791271   101179      NaN  2676118053972560256        445.011621  4373.41
# 1218897  101179       K5  2676118053972560256        445.011621  4373.41
# 791272   101227      NaN  2676907331522450432        721.980515  4914.56
# 1218898  101227       K0  2676907331522450432        721.980515  4914.56
# 815974   102002      NaN  2677134896069602688        599.234849  4420.36
#
#           logg      A_GG      A_BP      A_RP       A_J  ...  COLOR_A_J_A_KS  \
# 791271   4.678  6.767960  7.858309  6.180544  5.044074  ...        0.445446
# 1218897  4.678  6.767960  7.858309  6.180544  5.044074  ...        0.445446
# 791272   4.753  6.327260  6.928897  5.914654  4.761796  ...        0.282849
# 1218898  4.753  6.327260  6.928897  5.914654  4.761796  ...        0.282849
# 815974   4.734  6.469451  7.869586  6.355746  4.993796  ...        0.537656
#
#          COLOR_A_J_A_W1  COLOR_A_J_A_W2  COLOR_A_H_A_KS  COLOR_A_H_A_W1  \
# 791271         0.548842        0.399554        0.212207        0.315604
# 1218897        0.548842        0.399554        0.212207        0.315604
# 791272        -0.068439        0.480850        0.035260       -0.316029
# 1218898       -0.068439        0.480850        0.035260       -0.316029
# 815974         0.904860        0.902511       -0.157372        0.209831
#
#          COLOR_A_H_A_W2  COLOR_A_KS_A_W1  COLOR_A_KS_A_W2  COLOR_A_W1_A_W2  \
# 791271         0.166316         0.103396        -0.045892        -0.149288
# 1218897        0.166316         0.103396        -0.045892        -0.149288
# 791272         0.233261        -0.351288         0.198001         0.549289
# 1218898        0.233261        -0.351288         0.198001         0.549289
# 815974         0.207483         0.367203         0.364855        -0.002348
#
#          spectral_type_group
# 791271                     G
# 1218897                    K
# 791272                     G
# 1218898                    K
# 815974                     G
#
# [5 rows x 197 columns]

# %%
#overlapping_stars_df.head(30)

# %%
print("Missing values per column in overlapping_stars_df:")
missing = overlapping_stars_df.isnull().sum()
for col, count in missing.items():
    print(f"{col}: {count}")
# Out:
# Missing values per column in overlapping_stars_df:
# obsid: 0
# subclass: 403337
# gaia_source_id: 0
# distance_gaia_pc: 0
# teff: 0
# logg: 0
# A_GG: 0
# A_BP: 0
# A_RP: 0
# A_J: 0
# A_H: 0
# A_KS: 0
# A_W1: 0
# A_W2: 0
# A_BAP: 0
# A_VAP: 0
# A_RAP: 0
# A_GSD: 0
# A_RSD: 0
# A_ISD: 0
# A_ps_g: 0
# A_ps_r: 0
# A_ps_i: 0
# A_ps_z: 0
# A_ps_y: 0
# COLOR_A_BAP_A_GSD: 0
# COLOR_A_BAP_A_ps_g: 0
# COLOR_A_BAP_A_BP: 0
# COLOR_A_BAP_A_VAP: 0
# COLOR_A_BAP_A_ps_r: 0
# COLOR_A_BAP_A_RSD: 0
# COLOR_A_BAP_A_RAP: 0
# COLOR_A_BAP_A_GG: 0
# COLOR_A_BAP_A_ps_i: 0
# COLOR_A_BAP_A_ISD: 0
# COLOR_A_BAP_A_RP: 0
# COLOR_A_BAP_A_ps_z: 0
# COLOR_A_BAP_A_ps_y: 0
# COLOR_A_BAP_A_J: 0
# COLOR_A_BAP_A_H: 0
# COLOR_A_BAP_A_KS: 0
# COLOR_A_BAP_A_W1: 0
# COLOR_A_BAP_A_W2: 0
# COLOR_A_GSD_A_ps_g: 0
# COLOR_A_GSD_A_BP: 0
# COLOR_A_GSD_A_VAP: 0
# COLOR_A_GSD_A_ps_r: 0
# COLOR_A_GSD_A_RSD: 0
# COLOR_A_GSD_A_RAP: 0
# COLOR_A_GSD_A_GG: 0
# COLOR_A_GSD_A_ps_i: 0
# COLOR_A_GSD_A_ISD: 0
# COLOR_A_GSD_A_RP: 0
# COLOR_A_GSD_A_ps_z: 0
# COLOR_A_GSD_A_ps_y: 0
# COLOR_A_GSD_A_J: 0
# COLOR_A_GSD_A_H: 0
# COLOR_A_GSD_A_KS: 0
# COLOR_A_GSD_A_W1: 0
# COLOR_A_GSD_A_W2: 0
# COLOR_A_ps_g_A_BP: 0
# COLOR_A_ps_g_A_VAP: 0
# COLOR_A_ps_g_A_ps_r: 0
# COLOR_A_ps_g_A_RSD: 0
# COLOR_A_ps_g_A_RAP: 0
# COLOR_A_ps_g_A_GG: 0
# COLOR_A_ps_g_A_ps_i: 0
# COLOR_A_ps_g_A_ISD: 0
# COLOR_A_ps_g_A_RP: 0
# COLOR_A_ps_g_A_ps_z: 0
# COLOR_A_ps_g_A_ps_y: 0
# COLOR_A_ps_g_A_J: 0
# COLOR_A_ps_g_A_H: 0
# COLOR_A_ps_g_A_KS: 0
# COLOR_A_ps_g_A_W1: 0
# COLOR_A_ps_g_A_W2: 0
# COLOR_A_BP_A_VAP: 0
# COLOR_A_BP_A_ps_r: 0
# COLOR_A_BP_A_RSD: 0
# COLOR_A_BP_A_RAP: 0
# COLOR_A_BP_A_GG: 0
# COLOR_A_BP_A_ps_i: 0
# COLOR_A_BP_A_ISD: 0
# COLOR_A_BP_A_RP: 0
# COLOR_A_BP_A_ps_z: 0
# COLOR_A_BP_A_ps_y: 0
# COLOR_A_BP_A_J: 0
# COLOR_A_BP_A_H: 0
# COLOR_A_BP_A_KS: 0
# COLOR_A_BP_A_W1: 0
# COLOR_A_BP_A_W2: 0
# COLOR_A_VAP_A_ps_r: 0
# COLOR_A_VAP_A_RSD: 0
# COLOR_A_VAP_A_RAP: 0
# COLOR_A_VAP_A_GG: 0
# COLOR_A_VAP_A_ps_i: 0
# COLOR_A_VAP_A_ISD: 0
# COLOR_A_VAP_A_RP: 0
# COLOR_A_VAP_A_ps_z: 0
# COLOR_A_VAP_A_ps_y: 0
# COLOR_A_VAP_A_J: 0
# COLOR_A_VAP_A_H: 0
# COLOR_A_VAP_A_KS: 0
# COLOR_A_VAP_A_W1: 0
# COLOR_A_VAP_A_W2: 0
# COLOR_A_ps_r_A_RSD: 0
# COLOR_A_ps_r_A_RAP: 0
# COLOR_A_ps_r_A_GG: 0
# COLOR_A_ps_r_A_ps_i: 0
# COLOR_A_ps_r_A_ISD: 0
# COLOR_A_ps_r_A_RP: 0
# COLOR_A_ps_r_A_ps_z: 0
# COLOR_A_ps_r_A_ps_y: 0
# COLOR_A_ps_r_A_J: 0
# COLOR_A_ps_r_A_H: 0
# COLOR_A_ps_r_A_KS: 0
# COLOR_A_ps_r_A_W1: 0
# COLOR_A_ps_r_A_W2: 0
# COLOR_A_RSD_A_RAP: 0
# COLOR_A_RSD_A_GG: 0
# COLOR_A_RSD_A_ps_i: 0
# COLOR_A_RSD_A_ISD: 0
# COLOR_A_RSD_A_RP: 0
# COLOR_A_RSD_A_ps_z: 0
# COLOR_A_RSD_A_ps_y: 0
# COLOR_A_RSD_A_J: 0
# COLOR_A_RSD_A_H: 0
# COLOR_A_RSD_A_KS: 0
# COLOR_A_RSD_A_W1: 0
# COLOR_A_RSD_A_W2: 0
# COLOR_A_RAP_A_GG: 0
# COLOR_A_RAP_A_ps_i: 0
# COLOR_A_RAP_A_ISD: 0
# COLOR_A_RAP_A_RP: 0
# COLOR_A_RAP_A_ps_z: 0
# COLOR_A_RAP_A_ps_y: 0
# COLOR_A_RAP_A_J: 0
# COLOR_A_RAP_A_H: 0
# COLOR_A_RAP_A_KS: 0
# COLOR_A_RAP_A_W1: 0
# COLOR_A_RAP_A_W2: 0
# COLOR_A_GG_A_ps_i: 0
# COLOR_A_GG_A_ISD: 0
# COLOR_A_GG_A_RP: 0
# COLOR_A_GG_A_ps_z: 0
# COLOR_A_GG_A_ps_y: 0
# COLOR_A_GG_A_J: 0
# COLOR_A_GG_A_H: 0
# COLOR_A_GG_A_KS: 0
# COLOR_A_GG_A_W1: 0
# COLOR_A_GG_A_W2: 0
# COLOR_A_ps_i_A_ISD: 0
# COLOR_A_ps_i_A_RP: 0
# COLOR_A_ps_i_A_ps_z: 0
# COLOR_A_ps_i_A_ps_y: 0
# COLOR_A_ps_i_A_J: 0
# COLOR_A_ps_i_A_H: 0
# COLOR_A_ps_i_A_KS: 0
# COLOR_A_ps_i_A_W1: 0
# COLOR_A_ps_i_A_W2: 0
# COLOR_A_ISD_A_RP: 0
# COLOR_A_ISD_A_ps_z: 0
# COLOR_A_ISD_A_ps_y: 0
# COLOR_A_ISD_A_J: 0
# COLOR_A_ISD_A_H: 0
# COLOR_A_ISD_A_KS: 0
# COLOR_A_ISD_A_W1: 0
# COLOR_A_ISD_A_W2: 0
# COLOR_A_RP_A_ps_z: 0
# COLOR_A_RP_A_ps_y: 0
# COLOR_A_RP_A_J: 0
# COLOR_A_RP_A_H: 0
# COLOR_A_RP_A_KS: 0
# COLOR_A_RP_A_W1: 0
# COLOR_A_RP_A_W2: 0
# COLOR_A_ps_z_A_ps_y: 0
# COLOR_A_ps_z_A_J: 0
# COLOR_A_ps_z_A_H: 0
# COLOR_A_ps_z_A_KS: 0
# COLOR_A_ps_z_A_W1: 0
# COLOR_A_ps_z_A_W2: 0
# COLOR_A_ps_y_A_J: 0
# COLOR_A_ps_y_A_H: 0
# COLOR_A_ps_y_A_KS: 0
# COLOR_A_ps_y_A_W1: 0
# COLOR_A_ps_y_A_W2: 0
# COLOR_A_J_A_H: 0
# COLOR_A_J_A_KS: 0
# COLOR_A_J_A_W1: 0
# COLOR_A_J_A_W2: 0
# COLOR_A_H_A_KS: 0
# COLOR_A_H_A_W1: 0
# COLOR_A_H_A_W2: 0
# COLOR_A_KS_A_W1: 0
# COLOR_A_KS_A_W2: 0
# COLOR_A_W1_A_W2: 0
# spectral_type_group: 0

# %%
# --------------------------------------------------------------------------------
# TASK: Drop Duplicates & Save Consolidated Dataset
# --------------------------------------------------------------------------------

# 1. Drop duplicated rows based on 'obsid'
# Rule: keep='first' retains the entry from the higher priority spectral type 
# (F > G > K > M) based on the order of loading in 'load_consolidated_data'.
initial_len = len(df)
df_clean = df.drop_duplicates(subset=['obsid'], keep='first').reset_index(drop=True)
dropped_count = initial_len - len(df_clean)

print(f"Removing Duplicates: Dropped {dropped_count} rows. Final dataset size: {len(df_clean)} rows.")

# Update the main dataframe for subsequent analysis
df = df_clean

# 2. Save the final consolidated dataset
# Creating the directory if it doesn't exist
FINAL_DATA_DIR = Path(r'C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\data\logg_final_df')
FINAL_DATA_DIR.mkdir(parents=True, exist_ok=True)

output_path = FINAL_DATA_DIR / 'cool_dwarf_catalog_FGKM_consolidated.csv'
df.to_csv(output_path, index=False)
print(f"Saved processed dataset to: {output_path}")

# 3. Summary Table
print("\n=== Final Consolidated Dataset Summary ===")
summary_df = df['spectral_type_group'].value_counts().reset_index()
summary_df.columns = ['Spectral Type', 'Count']
display(summary_df)
# Out:
# Removing Duplicates: Dropped 403337 rows. Final dataset size: 904427 rows.
# Saved processed dataset to: C:\git_repo\cool-dwarf_stellar_parameter_inference_from_survey_data\data\logg_final_df\cool_dwarf_catalog_FGKM_consolidated.csv
#
# === Final Consolidated Dataset Summary ===
#   Spectral Type   Count
# 0             G  578786
# 1             F  274831
# 2             M   31921
# 3             K   18889

# %% [markdown]
# ## Phase 2: Color Calculation
#
# Defining the 18 color combinations using absolute magnitudes.

# %%
# Define ALL 19 distinct magnitudes sorted by center wavelength (shortest to longest)
sorted_mags = [
    'A_BAP', 'A_GSD', 'A_ps_g', 'A_BP', 'A_VAP', 'A_ps_r', 'A_RSD', 'A_RAP', 
    'A_GG', 'A_ps_i', 'A_ISD', 'A_RP', 'A_ps_z', 'A_ps_y', 'A_J', 'A_H', 
    'A_KS', 'A_W1', 'A_W2'
]

# Generate all 171 color combinations (shorter wavelength - longer wavelength)
color_combinations = {}
for i in range(len(sorted_mags)):
    for j in range(i + 1, len(sorted_mags)):
        mag1 = sorted_mags[i]
        mag2 = sorted_mags[j]
        color_name = f'COLOR_{mag1}_{mag2}'
        color_combinations[color_name] = (mag1, mag2)

print(f"Generated {len(color_combinations)} color combinations.")

# Re-calculate all colors to ensure they exist in the consolidated dataframe
for color_name, (mag1, mag2) in color_combinations.items():
    if mag1 in df.columns and mag2 in df.columns:
        df[color_name] = df[mag1] - df[mag2]

# --- MANUAL SELECTION ---
# Pick one representative color to calculate and plot
# Defaulting to Gaia BP - RP, a standard benchmark
SELECTED_COLOR = 'COLOR_A_ps_r_A_RSD'

if SELECTED_COLOR in color_combinations:
    mag1, mag2 = color_combinations[SELECTED_COLOR]
    print(f"\nSelected color for single test plot: {SELECTED_COLOR} = {mag1} - {mag2}")
    if SELECTED_COLOR not in df.columns:
        print(f"Error: Missing columns ({mag1} or {mag2}) to calculate {SELECTED_COLOR}")
else:
    print(f"Error: {SELECTED_COLOR} is not defined in color_combinations.")
# Out:
# Generated 171 color combinations.
#
# Selected color for single test plot: COLOR_A_ps_r_A_RSD = A_ps_r - A_RSD

# %% [markdown]
# ## Phase 3: Visualization Function
#
# Implementing the large-scale contour plot function.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from matplotlib.lines import Line2D

def plot_color_vs_logg_improved(data, color_col, save_path=None, contour_levels=10, contour_cmap='viridis'):
    """
    Improved plotting function with density contours (colored by density), 
    marginal histograms (the 'skyline'), and shuffled points to fix overlap.
    
    Parameters:
    - contour_levels: int, controls the granularity of the density lines (The "Knob").
    - contour_cmap: str, colormap for the contour lines (e.g., 'viridis', 'plasma', 'inferno').
    """
    # 1. Prepare Data
    # Drop NaNs for this specific view
    plot_df = data.dropna(subset=[color_col, 'logg']).copy()
    
    # Define a consistent palette (using 'husl' to match your style)
    spectral_order = ['F', 'G', 'K', 'M']
    palette = sns.color_palette("husl", 4) 
    color_map = dict(zip(spectral_order, palette))
    
    # 2. Setup the JointGrid (Main plot + Marginal histograms)
    # This automatically sets up the main box and the side panels
    g = sns.JointGrid(data=plot_df, x='logg', y=color_col, height=10, ratio=4)
    
    # 3. Main Scatter Plot (Randomized Order)
    # We shuffle the dataframe so 'M' stars don't always cover 'F' stars
    shuffled_df = plot_df.sample(frac=1, random_state=42)
    
    # Map colors to the shuffled data
    point_colors = shuffled_df['spectral_type_group'].map(color_map)
    
    # Plot transparent points
    g.ax_joint.scatter(
        shuffled_df['logg'], 
        shuffled_df[color_col], 
        c=point_colors, 
        s=15, 
        alpha=0.15, # Slightly lower opacity since contours are now colored
        edgecolor='none'
    )
    
    # 4. Density Contours
    # We calculate the density of the ENTIRE dataset to find the global "peaks"
    try:
        # Define grid limits
        x = plot_df['logg']
        y = plot_df[color_col]
        xmin, xmax = x.min(), x.max()
        ymin, ymax = y.min(), y.max()
        
        # Create a meshgrid for the contour calculation
        xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
        positions = np.vstack([xx.ravel(), yy.ravel()])
        
        # Performance optimization: Subsample for KDE if data is massive (>50k rows)
        if len(plot_df) > 50000:
            kde_data = plot_df.sample(50000, random_state=42)
            kde_values = np.vstack([kde_data['logg'], kde_data[color_col]])
            kernel = stats.gaussian_kde(kde_values)
        else:
            values = np.vstack([x, y])
            kernel = stats.gaussian_kde(values)
            
        f = np.reshape(kernel(positions).T, xx.shape)
        
        # Draw the contour lines COLORED BY DENSITY
        # 'cmap' maps the density values to colors. 'linewidths' makes them visible.
        g.ax_joint.contour(
            xx, yy, f, 
            cmap=contour_cmap, 
            linewidths=1.0,  # Thinner lines
            levels=contour_levels  # Granularity knob
        )
        
        # REMOVED: clabel block to remove number labels
        
    except Exception as e:
        print(f"Could not plot contours for {color_col}: {e}")

    # 5. Marginal Plots (The "Span")
    # Show the density distribution for EACH spectral type on the side axes
    sns.kdeplot(data=plot_df, x='logg', hue='spectral_type_group', hue_order=spectral_order,
                palette=color_map, ax=g.ax_marg_x, fill=True, legend=False, alpha=0.3, linewidth=2)
    
    sns.kdeplot(data=plot_df, y=color_col, hue='spectral_type_group', hue_order=spectral_order,
                palette=color_map, ax=g.ax_marg_y, fill=True, legend=False, alpha=0.3, linewidth=2)

    # 6. Formatting & Legend
    g.ax_joint.set_xlabel("logg", fontsize=16)
    g.ax_joint.set_ylabel(f"{color_col} (mag)", fontsize=16)
    g.fig.suptitle(f"Color vs logg: {color_col}", fontsize=20, y=1.02)
    g.ax_joint.grid(True, linestyle='--', alpha=0.5)
    
    # Custom Legend
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label=stype, 
               markerfacecolor=color_map[stype], markersize=10)
        for stype in spectral_order
    ]
    g.ax_joint.legend(handles=legend_elements, title="Spectral Type", loc='upper left')

    if save_path:
        g.savefig(save_path, dpi=200, bbox_inches='tight')
        
    return g

# %% [markdown]
# ## Phase 4: Single Color Test (Sanity Check 2)

# %%
# Settings for the plots
GRANULARITY_KNOB = 12    # Increase for more detail (more lines), Decrease for smoother look
CONTOUR_COLORMAP = 'magma' # Try: 'viridis', 'plasma', 'inferno', 'magma', 'cividis'

# Re-using the SELECTED_COLOR variable defined in an earlier cell.
# If you want to change the color, update SELECTED_COLOR in the cell above (Phase 2).

if 'SELECTED_COLOR' in locals() and SELECTED_COLOR in df.columns:
    print(f"Generating improved plot for {SELECTED_COLOR}...")
    save_name = RESULTS_DIR / f"{SELECTED_COLOR}_vs_logg_improved.png"
    
    # Clear memory before plotting
    plt.close('all') 
    
    plot_color_vs_logg_improved(
        df, 
        SELECTED_COLOR, 
        save_path=save_name, 
        contour_levels=GRANULARITY_KNOB, 
        contour_cmap=CONTOUR_COLORMAP
    )
    
    plt.show() # Display the plot inline
else:
    if 'SELECTED_COLOR' not in locals():
        print(f"Error: SELECTED_COLOR is not defined. Please run the cell in Phase 2 first.")
    else:
        print(f"Error: The selected color '{SELECTED_COLOR}' was not found in the dataframe columns.")
# Out:
# Generating improved plot for COLOR_A_ps_r_A_RSD...
